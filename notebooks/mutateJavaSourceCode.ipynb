# %% [markdown]
# ## Mutating a Code Excerpt Using LittleDarwin
#
# Have you ever wondered what you need to mutate a Java code excerpt? All you need is the help of LittleDarwin!
# In this notebook, we are going to see how this can be done, and what you can do with the machinery LittleDarwin provides for you.
#
# Consider this very simple piece of code:
#
#     public class MyCode {
#
#         void bubbleSort(int array[]) {
#             int len = array.length;
#             for (int i = 0; i < len - 1; i++)
#                 for (int j = 0; j < len - i - 1; j++)
#                     if (array[j] > array[j+1]) {
#                         int temp = array[j];
#                         array[j] = array[j+1];
#                         arr[j+1] = temp;
#                     }
#         }
#     }
#
# First, we need to write some Python code, because LittleDarwin is written in Python for some reason.
#
#
# We wrap the code in a string:

# %%
myJavaCode = """

public class MyCode {

  void bubbleSort(int array[])
    {
        int len = array.length;
        for (int i = 0; i < len - 1; i++)
            for (int j = 0; j < len - i - 1; j++)
                if (array[j] > array[j+1])
                {
                    int temp = array[j];
                    array[j] = array[j+1];
                    arr[j+1] = temp;
                }
    }
}


"""

# %% [markdown]
# Now we need to summon the knights of LittleDarwin: JavaParse and JavaMutate:

# %%
from mediumdarwin import JavaParse
from mediumdarwin import JavaMutate

# %% [markdown]
# Then, we initiate the parser, and retrieve the parse tree:

# %%
myParser = JavaParse.JavaParse()
myParseTree = myParser.parse(myJavaCode)

# %% [markdown]
# Now we can initiate the mutator by giving it all it wants: the parse tree, source code, and the JavaParse instance.
# We can then execute *gatherMutants* method to retrieve all the mutants the knights of LittleDarwin could create.

# %%
myMutator = JavaMutate.JavaMutate(sourceTree=myParseTree,
                    sourceCode=myJavaCode,
                    javaParseObject=myParser,
                    file_name="test.java")
mutantTypes = myMutator.gatherMutations(metaTypes=["All"])
#  mutants, mutantTypes = myMutator.gatherMutants()
mutants = myMutator.gatherAllMutantsUpToTheOrderOf(
                cur_order=1,                
                mutations=myMutator.mutations,
                generated_mutants=[],                
            )

# %% [markdown]
# At this point, the job is done. You have two things back from this quest: a bunch of mutants in a list, and a dictionary that tells you how many of each mutant type there is.

# %%
for mt in mutants:
    print("------------------------------------------------------------------\n")
    print(mt)
    print("------------------------------------------------------------------\n")
# Out:
# ------------------------------------------------------------------
#
# /* MediumDarwin generated order-1 mutant
#
# ----> mutantID: 0
#
# mutant type: ArithmeticOperatorReplacementShortcut
# ----> before:             for (int j = 0; j < len - i - 1; j++)
# ----> after:             for (int j = 0; j < len - i - 1; j/*MUT0*\/--)
# ----> line number in original file: 9
# ----> mutated node: 134
# ----> mutation ID: 0
#
# */
#
#
#
# public class MyCode {
#
#   void bubbleSort(int array[])
#     {
#         int len = array.length;
#         for (int i = 0; i < len - 1; i++)
#             for (int j = 0; j < len - i - 1; j/*MUT0*/--)
#                 if (array[j] > array[j+1])
#                 {
#                     int temp = array[j];
#                     array[j] = array[j+1];
#                     arr[j+1] = temp;
#                 }
#     }
# }
#
#
#
# ------------------------------------------------------------------
#
# ------------------------------------------------------------------
#
# /* MediumDarwin generated order-1 mutant
#
# ----> mutantID: 1
#
# mutant type: ArithmeticOperatorReplacementShortcut
# ----> before:         for (int i = 0; i < len - 1; i++)
# ----> after:         for (int i = 0; i < len - 1; i/*MUT1*\/--)
# ----> line number in original file: 8
# ----> mutated node: 86
# ----> mutation ID: 1
#
# */
#
#
#
# public class MyCode {
#
#   void bubbleSort(int array[])
#     {
#         int len = array.length;
#         for (int i = 0; i < len - 1; i/*MUT1*/--)
#             for (int j = 0; j < len - i - 1; j++)
#                 if (array[j] > array[j+1])
#                 {
#                     int temp = array[j];
#                     array[j] = array[j+1];
#                     arr[j+1] = temp;
#                 }
#     }
# }
#
#
#
# ------------------------------------------------------------------
#
# ------------------------------------------------------------------
#
# /* MediumDarwin generated order-1 mutant
#
# ----> mutantID: 2
#
# mutant type: ArithmeticOperatorReplacementBinary
# ----> before:                     arr[j+1] = temp;
# ----> after:                     arr[j/*MUT2*\/-1] = temp;
# ----> line number in original file: 14
# ----> mutated node: 235
# ----> mutation ID: 2
#
# */
#
#
#
# public class MyCode {
#
#   void bubbleSort(int array[])
#     {
#         int len = array.length;
#         for (int i = 0; i < len - 1; i++)
#             for (int j = 0; j < len - i - 1; j++)
#                 if (array[j] > array[j+1])
#                 {
#                     int temp = array[j];
#                     array[j] = array[j+1];
#                     arr[j/*MUT2*/-1] = temp;
#                 }
#     }
# }
#
#
#
# ------------------------------------------------------------------
#
# ------------------------------------------------------------------
#
# /* MediumDarwin generated order-1 mutant
#
# ----> mutantID: 3
#
# mutant type: ArithmeticOperatorReplacementBinary
# ----> before:                     array[j] = array[j+1];
# ----> after:                     array[j] = array[j/*MUT3*\/-1];
# ----> line number in original file: 13
# ----> mutated node: 215
# ----> mutation ID: 3
#
# */
#
#
#
# public class MyCode {
#
#   void bubbleSort(int array[])
#     {
#         int len = array.length;
#         for (int i = 0; i < len - 1; i++)
#             for (int j = 0; j < len - i - 1; j++)
#                 if (array[j] > array[j+1])
#                 {
#                     int temp = array[j];
#                     array[j] = array[j/*MUT3*/-1];
#                     arr[j+1] = temp;
#                 }
#     }
# }
#
#
#
# ------------------------------------------------------------------
#
# ------------------------------------------------------------------
#
# /* MediumDarwin generated order-1 mutant
#
# ----> mutantID: 4
#
# mutant type: ArithmeticOperatorReplacementBinary
# ----> before:                 if (array[j] > array[j+1])
# ----> after:                 if (array[j] > array[j/*MUT4*\/-1])
# ----> line number in original file: 10
# ----> mutated node: 160
# ----> mutation ID: 4
#
# */
#
#
#
# public class MyCode {
#
#   void bubbleSort(int array[])
#     {
#         int len = array.length;
#         for (int i = 0; i < len - 1; i++)
#             for (int j = 0; j < len - i - 1; j++)
#                 if (array[j] > array[j/*MUT4*/-1])
#                 {
#                     int temp = array[j];
#                     array[j] = array[j+1];
#                     arr[j+1] = temp;
#                 }
#     }
# }
#
#
#
# ------------------------------------------------------------------
#
# ------------------------------------------------------------------
#
# /* MediumDarwin generated order-1 mutant
#
# ----> mutantID: 5
#
# mutant type: ArithmeticOperatorReplacementBinary
# ----> before:             for (int j = 0; j < len - i - 1; j++)
# ----> after:             for (int j = 0; j < len - i /*MUT5*\/+ 1; j++)
# ----> line number in original file: 9
# ----> mutated node: 117
# ----> mutation ID: 5
#
# */
#
#
#
# public class MyCode {
#
#   void bubbleSort(int array[])
#     {
#         int len = array.length;
#         for (int i = 0; i < len - 1; i++)
#             for (int j = 0; j < len - i /*MUT5*/+ 1; j++)
#                 if (array[j] > array[j+1])
#                 {
#                     int temp = array[j];
#                     array[j] = array[j+1];
#                     arr[j+1] = temp;
#                 }
#     }
# }
#
#
#
# ------------------------------------------------------------------
#
# ------------------------------------------------------------------
#
# /* MediumDarwin generated order-1 mutant
#
# ----> mutantID: 6
#
# mutant type: ArithmeticOperatorReplacementBinary
# ----> before:             for (int j = 0; j < len - i - 1; j++)
# ----> after:             for (int j = 0; j < len /*MUT6*\/+ i - 1; j++)
# ----> line number in original file: 9
# ----> mutated node: 118
# ----> mutation ID: 6
#
# */
#
#
#
# public class MyCode {
#
#   void bubbleSort(int array[])
#     {
#         int len = array.length;
#         for (int i = 0; i < len - 1; i++)
#             for (int j = 0; j < len /*MUT6*/+ i - 1; j++)
#                 if (array[j] > array[j+1])
#                 {
#                     int temp = array[j];
#                     array[j] = array[j+1];
#                     arr[j+1] = temp;
#                 }
#     }
# }
#
#
#
# ------------------------------------------------------------------
#
# ------------------------------------------------------------------
#
# /* MediumDarwin generated order-1 mutant
#
# ----> mutantID: 7
#
# mutant type: ArithmeticOperatorReplacementBinary
# ----> before:         for (int i = 0; i < len - 1; i++)
# ----> after:         for (int i = 0; i < len /*MUT7*\/+ 1; i++)
# ----> line number in original file: 8
# ----> mutated node: 74
# ----> mutation ID: 7
#
# */
#
#
#
# public class MyCode {
#
#   void bubbleSort(int array[])
#     {
#         int len = array.length;
#         for (int i = 0; i < len /*MUT7*/+ 1; i++)
#             for (int j = 0; j < len - i - 1; j++)
#                 if (array[j] > array[j+1])
#                 {
#                     int temp = array[j];
#                     array[j] = array[j+1];
#                     arr[j+1] = temp;
#                 }
#     }
# }
#
#
#
# ------------------------------------------------------------------
#
# ------------------------------------------------------------------
#
# /* MediumDarwin generated order-1 mutant
#
# ----> mutantID: 8
#
# mutant type: RemoveMethod
# ----> before:     {
# ----> after:     {/*MUT8*\/return;}
# ----> line number in original file: 6
# ----> mutated node: 27
# ----> mutation ID: 8
#
# */
#
#
#
# public class MyCode {
#
#   void bubbleSort(int array[])
#     {/*MUT8*/return;}
# }
#
#
#
# ------------------------------------------------------------------
#
# ------------------------------------------------------------------
#
# /* MediumDarwin generated order-1 mutant
#
# ----> mutantID: 9
#
# mutant type: RelationalOperatorReplacement
# ----> before:                 if (array[j] > array[j+1])
# ----> after:                 if (array[j] /*MUT9*\/<= array[j+1])
# ----> line number in original file: 10
# ----> mutated node: 144
# ----> mutation ID: 9
#
# */
#
#
#
# public class MyCode {
#
#   void bubbleSort(int array[])
#     {
#         int len = array.length;
#         for (int i = 0; i < len - 1; i++)
#             for (int j = 0; j < len - i - 1; j++)
#                 if (array[j] /*MUT9*/<= array[j+1])
#                 {
#                     int temp = array[j];
#                     array[j] = array[j+1];
#                     arr[j+1] = temp;
#                 }
#     }
# }
#
#
#
# ------------------------------------------------------------------
#
# ------------------------------------------------------------------
#
# /* MediumDarwin generated order-1 mutant
#
# ----> mutantID: 10
#
# mutant type: RelationalOperatorReplacement
# ----> before:             for (int j = 0; j < len - i - 1; j++)
# ----> after:             for (int j = 0; j /*MUT10*\/>= len - i - 1; j++)
# ----> line number in original file: 9
# ----> mutated node: 112
# ----> mutation ID: 10
#
# */
#
#
#
# public class MyCode {
#
#   void bubbleSort(int array[])
#     {
#         int len = array.length;
#         for (int i = 0; i < len - 1; i++)
#             for (int j = 0; j /*MUT10*/>= len - i - 1; j++)
#                 if (array[j] > array[j+1])
#                 {
#                     int temp = array[j];
#                     array[j] = array[j+1];
#                     arr[j+1] = temp;
#                 }
#     }
# }
#
#
#
# ------------------------------------------------------------------
#
# ------------------------------------------------------------------
#
# /* MediumDarwin generated order-1 mutant
#
# ----> mutantID: 11
#
# mutant type: RelationalOperatorReplacement
# ----> before:         for (int i = 0; i < len - 1; i++)
# ----> after:         for (int i = 0; i /*MUT11*\/>= len - 1; i++)
# ----> line number in original file: 8
# ----> mutated node: 69
# ----> mutation ID: 11
#
# */
#
#
#
# public class MyCode {
#
#   void bubbleSort(int array[])
#     {
#         int len = array.length;
#         for (int i = 0; i /*MUT11*/>= len - 1; i++)
#             for (int j = 0; j < len - i - 1; j++)
#                 if (array[j] > array[j+1])
#                 {
#                     int temp = array[j];
#                     array[j] = array[j+1];
#                     arr[j+1] = temp;
#                 }
#     }
# }
#
#
#
# ------------------------------------------------------------------

# %%
for mtType in mutantTypes.keys():
    if mutantTypes[mtType] > 0:
        print(mtType, ":", mutantTypes[mtType])
# Out:
# ArithmeticOperatorReplacementShortcut : 2
# ArithmeticOperatorReplacementBinary : 6
# RemoveMethod : 1
# RelationalOperatorReplacement : 3

# %% [markdown]
# That's all folks! More complicated stuff coming soon.
